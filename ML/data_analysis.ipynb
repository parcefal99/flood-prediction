# %%
import xarray as xr
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = xr.load_dataset("../data/CAMELS_KZ/time_series/12072.nc")
ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:         (date: 8766)
# Coordinates:
#   * date            (date) datetime64[ns] 70kB 2000-01-01 ... 2023-12-31
# Data variables: (12/30)
#     station         (date) <U9 316kB 'Karabalyk' 'Karabalyk' ... 'Karabalyk'
#     t_mean          (date) float64 70kB -17.9 -28.5 -29.8 ... -5.0 -10.0 -12.3
#     t_max           (date) float64 70kB -13.7 -21.8 -24.9 ... 0.7 -7.3 -2.1
#     t_min           (date) float64 70kB -21.9 -34.9 -34.8 ... -9.6 -11.4 -19.6
#     st_mean         (date) int64 70kB -17 -28 -28 -17 -14 ... -5 -3 -6 -12 -15
#     st_max          (date) int64 70kB -14 -20 -23 -13 -11 -9 ... -4 -1 0 -7 -4
#     ...              ...
#     srad            (date) float64 70kB 31.61 55.14 39.11 ... 46.14 51.17 41.67
#     dayl            (date) float64 70kB 2.704e+04 2.711e+04 ... 2.698e+04
#     discharge       (date) float64 70kB nan nan nan nan nan ... nan nan nan nan
# ...

# %%
df = ds.to_dataframe()
df.head()
# Out:
#               station  t_mean  t_max  t_min  st_mean  st_max  st_min  dew_min  \
# date
# 2000-01-01  Karabalyk   -17.9  -13.7  -21.9      -17     -14     -21    -25.0
# 2000-01-02  Karabalyk   -28.5  -21.8  -34.9      -28     -20     -36    -37.7
# 2000-01-03  Karabalyk   -29.8  -24.9  -34.8      -28     -23     -36    -37.4
# 2000-01-04  Karabalyk   -18.3  -13.7  -25.7      -17     -13     -25    -26.6
# 2000-01-05  Karabalyk   -14.0  -12.1  -18.6      -14     -11     -21    -21.1
#
#             pp_mean  hum_mean  ...  prcp  soil  snow_cover  snow_height  \
# date                           ...
# 2000-01-01    125.0      80.0  ...   1.9     7        10.0         23.0
# 2000-01-02     47.0      76.0  ...   0.7     7        10.0         24.0
# 2000-01-03     41.0      74.0  ...   0.0     7        10.0         24.0
# 2000-01-04    101.0      68.0  ...   0.0     7        10.0         24.0
# 2000-01-05    150.0      72.0  ...   0.5     7        10.0         24.0
#
# ...

# %%
plt.plot(df.discharge)

# %%
ds = xr.load_dataset("../data/fancy_dataset/time_series/11001.nc")

# %%
df = ds.to_dataframe()
df.head()
# Out:
#             prcp_era  prcp_mswep  prcp_gsmap  prcp_chirps     t_mean  \
# date
# 2000-01-01  2.474655    3.615665         NaN     4.199566 -19.142680
# 2000-01-02  4.740930    4.379445         NaN     0.715496 -15.311616
# 2000-01-03  0.435887    0.388336         NaN     0.000000 -25.296625
# 2000-01-04  0.030327    0.019292         NaN     0.000000 -32.051096
# 2000-01-05  0.008101    0.002045         NaN     0.000000 -30.493077
#
#                 t_min      t_max   dew_mean  wind_speed         vp1  \
# date
# 2000-01-01 -27.859099 -15.783554 -23.930457    2.146215   90.018000
# 2000-01-02 -18.856169 -12.935970 -17.561182    0.660714  156.326808
# 2000-01-03 -30.339727 -19.247853 -28.315138    1.506855   60.428455
# 2000-01-04 -36.605804 -27.880391 -36.268178    0.925259   28.126723
# 2000-01-05 -36.630271 -24.746864 -37.458894    2.367154   24.960799
#
#                    vp2       srad  discharge
# date
# 2000-01-01   88.045440  40.760515   0.132061
# ...
